# %% [markdown]
# <a href="https://colab.research.google.com/github/pronsSec/PronsSec-Scans-Your-Site/blob/main/PronsSec_Scans_Your_Site.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Prons Sec Scans Your Shit (1).png](data:image/png;base64,...)

# %% [markdown]
# ---
# ---
# This will help you determine if your site has any significant security vulnerabilities. This is one of the main tools used by web app penetration testers. You can help save some time and trouble by running this on your site, and sending the results to your web designer.
#
# ---
#
#
#
# ---
#
#
# > *You can only use this on sites you own! It is a crime to use this on sites you do not own...without permission. There are no guarantees or assurances provided by the creator of this notebook. This is an open source tool.*
# ---
# ---

# %% [markdown]
# ![Prons Sec Scans Your Shit (2).png](data:image/png;base64,...)

# %% [markdown]
# ---
# ---

# %%
#@title #Input Site Name Here. Then Press Play. { display-mode: "form" }
#@markdown ---

from IPython.display import clear_output
import IPython
def scan():
  # !git clone https://github.com/sullo/nikto
  # %cd nikto/program
  clear_output()
  Your_Site_Name = "" #@param {type:"string"}
  url = "https://" + Your_Site_Name + '/'
  # !./nikto.pl -h $url -output report.html 
  IPython.display.HTML(filename='report.html')
#@markdown ---
scan()

# %% [markdown]
# ---
# ---

# %%
#@title Click Here To Save Your Report { display-mode: "form" }
from google.colab import files



files.download('report.html')

# %% [markdown]
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
#
#
#
#
#
# If you need a special port just use ":port"
#
# examples: www/.fakesite.com or www/.fakesite.com:80
#
# ---
# This tool can create a dos event on your site (if it super sucks). Please ask your web designer if this is appropriate. TBH if that happens it's still something you should fix.
